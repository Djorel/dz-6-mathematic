# %%
#1
import numpy as np
from scipy.optimize import differential_evolution
def ackley(x):
    arg1 = -0.2 * np.sqrt(0.5 * (x[0] ** 2 + x[1] ** 2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x[0]) + np.cos(2. * np.pi * x[1]))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e
bounds = [(0,5), (0,5), (0,5), (0,5),(0,5)]
fx = ackley
result = differential_evolution(ackley, bounds, strategy = 'best2exp', popsize = 10, tol = 0.001, mutation = 1.5, recombination=0.5, seed=42, updating='deferred')
result
# Out:
#      fun: 6.065729696302924e-09
#  message: 'Maximum number of iterations has been exceeded.'
#     nfev: 50056
#      nit: 1000
#  success: False
#        x: array([2.07847251e-09, 5.28283639e-10, 2.94460479e+00, 2.40432014e+00,
#        6.55695616e-01])

# %%
result.x, result.fun
# Out:
# (array([2.07847251e-09, 5.28283639e-10, 2.94460479e+00, 2.40432014e+00,
#         6.55695616e-01]),
#  6.065729696302924e-09)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(result.x)
plt.show()

# %%
#2
import numpy as np
from scipy.optimize import differential_evolution
def ackley(x):
    arg1 = -0.2 * np.sqrt(0.5 * (x[0] ** 2 + x[1] ** 2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x[0]) + np.cos(2. * np.pi * x[1]))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e
bounds = [(0,5), (0,5), (0,5), (0,5),(0,5)]
fx = ackley
result = differential_evolution(ackley, bounds, strategy = 'rand1bin', popsize = 2, tol = 0.1, mutation = 1.9, recombination=0.9, seed=42, updating='immediate')
result
# Out:
#      fun: 3.222166573557672e-07
#  message: 'Optimization terminated successfully.'
#     nfev: 2676
#      nit: 266
#  success: True
#        x: array([6.91563709e-08, 9.05279798e-08, 4.65440332e-01, 1.89034892e+00,
#        4.26727114e+00])

# %%
result.x, result.fun
# Out:
# (array([6.91563709e-08, 9.05279798e-08, 4.65440332e-01, 1.89034892e+00,
#         4.26727114e+00]),
#  3.222166573557672e-07)

# %%
plt.figure(figsize=(10,7))
plt.plot(result.x)
plt.show()
